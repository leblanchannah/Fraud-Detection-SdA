# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import csv
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import keras.backend as K
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model,Sequential
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import impyute as impy

# %% [markdown]
# Information given - This data is derived from company accounts, part of quarterly filings to the SEC.
# The attribute names are common abbreviations for accountingterms. Adjacent lines are probably from the same company in different
# quarters, but we don't have any information about this. The fraud labels are from the SEC and so are probably conservative.
#
# Data from - https://www.thecaq.org/sites/default/files/DECHOW_et_al-2011-Contemporary_Accounting_Research.pdf
#
# Dechow, Patricia M. and Ge, Weili and Larson, Chad Russell and Sloan, Richard G., Predicting Material Accounting Misstatements (April 21, 2010). Contemporary Accounting Research, Forthcoming; AAA 2008 Financial Accounting and Reporting Section (FARS) Paper. Available at SSRN: https://ssrn.com/abstract=997483
#
# CISC873 Data Mining

# %%
# import data
y_all = pd.read_csv('fraudlabels.csv',names=["fraud"])
# feature names and data are in different csv files
with open(r"attributes.csv","r", encoding='utf8') as f:
    cr = csv.reader(f,delimiter=" ")
    features = list(cr)  # create a list of rows for instance
features = [x[0] for x in features]
X_all = pd.read_csv('fraudnumerics.csv',names=features)
# no type conversions required

# %%
X_all.describe()
# Out:
#                 act            at            ceq            che         csho  \
# count   2694.000000  3.013000e+03    3010.000000    3013.000000  2997.000000
# mean    1462.873078  2.341197e+04    2527.520349    2512.328737   197.116555
# std     4511.158009  1.235958e+05   10016.893438   16876.461511   568.163673
# min        0.000000  0.000000e+00  -13472.000000       0.000000     0.000000
# 25%       19.349250  3.523600e+01      10.928000       2.553000     8.610000
# 50%      102.387500  2.505770e+02      90.424000      20.121000    23.017000
# 75%      610.854750  2.413516e+03     699.240000     138.623000    93.417000
# max    53177.000000  2.187631e+06  152027.000000  292147.000000  5194.643000
#
#                  dlc          dltis           dltt          emp            ib  \
# count    3005.000000    2859.000000    3010.000000  2795.000000   3002.000000
# mean     5067.761700    1877.454229    4123.522644    16.027021    237.474487
# std     35051.678367   14556.957700   28479.929699    41.202681   1852.498517
# min         0.000000       0.000000       0.000000     0.000000 -44574.000000
# 25%         0.137000       0.000000       0.265250     0.250000     -4.480500
# 50%         3.332000       2.250000      19.468500     1.350000      2.977500
# 75%        47.307000     129.836000     522.623500    11.000000     49.661000
# max    562857.000000  347108.000000  486876.000000   387.000000  21249.000000
#
#           ...            ch-rec       ch-inv             cs         ch-cs  \
# count     ...       2934.000000  2877.000000    2924.000000   2829.000000
# mean      ...          0.024017     0.015064    4678.505849     37.690723
# std       ...          0.153149     0.122274   17844.118305   1877.922020
# min       ...         -1.125664    -1.130151 -138086.000000  -6409.593000
# 25%       ...         -0.014195    -0.003009      38.454750     -0.089824
# 50%       ...          0.011610     0.000504     235.223000      0.081467
# 75%       ...          0.061141     0.032312    2099.268250      0.326917
# max       ...          1.761902     1.352156  475726.000000  99115.480000
#
#           earn-ATA      ch-earn        ch-emp        issue            bm  \
# count  2928.000000  2843.000000   2615.000000  2758.000000   2782.000000
# mean     -0.098437     0.009133    -19.091415     0.935460     -5.425139
# std       0.877106     0.987890    837.128593     0.245756    225.910028
# min     -30.779660   -28.368890 -40259.410000     0.000000 -11675.760000
# 25%      -0.054855    -0.046190     -0.179945     1.000000      0.194625
# 50%       0.019645     0.000204     -0.041145     1.000000      0.388695
# 75%       0.067156     0.040111      0.070590     1.000000      0.654723
# max       2.337731    27.071180   6112.802000     1.000000     96.329620
#
#           new-comp
# count  3157.000000
# mean    127.155844
# std      75.631635
# min       1.000000
# 25%      62.000000
# 50%     125.000000
# 75%     192.000000
# max     260.000000
#
# [8 rows x 44 columns]

# %%
X_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3157 entries, 0 to 3156
# Data columns (total 44 columns):
# act           2694 non-null float64
# at            3013 non-null float64
# ceq           3010 non-null float64
# che           3013 non-null float64
# csho          2997 non-null float64
# dlc           3005 non-null float64
# dltis         2859 non-null float64
# dltt          3010 non-null float64
# emp           2795 non-null float64
# ib            3002 non-null float64
# invt          2963 non-null float64
# ivao          2806 non-null float64
# ivst          2936 non-null float64
# lct           2712 non-null float64
# lt            3010 non-null float64
# pstk          3006 non-null float64
# rect          3010 non-null float64
# sale          3002 non-null float64
# sstk          2864 non-null float64
# exchg         3157 non-null int64
# prcc-f        2803 non-null float64
# ret-t         2008 non-null float64
# ret-t1        1950 non-null float64
# vwretd        2008 non-null float64
# vwretd-t1     0 non-null float64
# oplease       3157 non-null float64
# lease-dum     3157 non-null int64
# r-vwretd      2008 non-null float64
# r-1-vwretd    1950 non-null float64
# WC            2693 non-null float64
# NCO           2490 non-null float64
# FIN           2719 non-null float64
# ATA           2938 non-null float64
# rsst-acc      2288 non-null float64
# ch-rec        2934 non-null float64
# ch-inv        2877 non-null float64
# cs            2924 non-null float64
# ch-cs         2829 non-null float64
# earn-ATA      2928 non-null float64
# ch-earn       2843 non-null float64
# ch-emp        2615 non-null float64
# issue         2758 non-null float64
# bm            2782 non-null float64
# new-comp      3157 non-null int64
# dtypes: float64(41), int64(3)
# memory usage: 1.1 MB

# %% [markdown]
# ### Comparing missing values in each class

# %%
# for all fraud labels which are the most commonly missing features
# comparing missing labels for each class 
fraud_df = X_all.loc[y_all[y_all.fraud == 1].index]
normal_df = X_all.loc[y_all[y_all.fraud == 0].index]
missing_fraud = pd.DataFrame({"null_fraud":fraud_df.isnull().sum().sort_values(ascending=False)})
missing_normal = pd.DataFrame({"null_normal":normal_df.isnull().sum().sort_values(ascending=False)})
print(missing_fraud.head(20))
print(missing_normal.head(20))
# Out:
#             null_fraud
# vwretd-t1          629
# ret-t1             153
# r-1-vwretd         153
# ret-t              146
# vwretd             146
# r-vwretd           146
# rsst-acc           140
# NCO                111
# ch-emp              82
# lct                 72
# WC                  72
# act                 72
# FIN                 60
# issue               56
# emp                 50
# ivao                48
# dltis               35
# ch-cs               35
# ch-earn             33
# sstk                33
#             null_normal
# vwretd-t1          2528
# ret-t1             1054
# r-1-vwretd         1054
# ret-t              1003
# vwretd             1003
# r-vwretd           1003
# rsst-acc            729
# NCO                 556
# ch-emp              460
# WC                  392
# act                 391
# FIN                 378
# lct                 373
# bm                  344
# issue               343
# prcc-f              332
# emp                 312
# ivao                303
# ch-cs               293
# ch-earn             281

# %%
# comparing missing values in rows for each class
# number of missing values in a row 
temp_Xf = pd.DataFrame({"rownull":fraud_df.isnull().sum(axis=1)})
temp_Xn = pd.DataFrame({"rownull":normal_df.isnull().sum(axis=1)})


print("average missing # missing values in fraud: ", round(temp_Xf.rownull.values.mean(),2))
print("average missing # missing values in normal: ",round(temp_Xn.rownull.values.mean(),2))

plt.hist(temp_Xf.rownull, 10, alpha=0.5, label='Fraud', normed=True)
plt.hist(temp_Xn.rownull, 10, alpha=0.5, label='Normal',normed=True)
plt.legend(loc='upper right')
plt.show()
# Out:
# average missing # missing values in fraud:  4.03
# average missing # missing values in normal:  6.6

# %%
# bar graph for missing values in pandas dataframe
# all missing values - not sectioned by class
objects = features
y_pos = np.arange(len(objects))
missing = pd.DataFrame({"null":X_all.isnull().sum().sort_values()})
plt.figure(figsize=(20,10))
plt.bar(y_pos, missing["null"], align='center', alpha=0.5)
plt.xticks(y_pos, missing.index, rotation='vertical')
plt.ylabel('')
plt.title('Missing Values')
plt.show()

# %% [markdown]
# ### Dropping Columns

# %%
# count NaN values in each column
missing['missing/total']  = missing['null']/ X_all.shape[0]
print(missing.head())
# delete data with more than 25% data missing
# get columns that fit into this category 
drop_rate = 0.25
to_drop = missing.index[missing['missing/total'] > drop_rate].tolist()
print(to_drop)
# Out:
#            null  missing/total
# new-comp      0       0.000000
# lease-dum     0       0.000000
# oplease       0       0.000000
# exchg         0       0.000000
# at          144       0.045613
# ['rsst-acc', 'r-vwretd', 'vwretd', 'ret-t', 'r-1-vwretd', 'ret-t1', 'vwretd-t1']

# %%
print("X shape: ", X_all.shape)
print("y shape: ",y_all.shape)
#dropping columns with more than 25% of data missing until I find out column labels
X_all = X_all.drop(columns=to_drop)
print("X shape: ", X_all.shape)
# Out:
# X shape:  (3157, 44)
# y shape:  (3157, 1)
# X shape:  (3157, 37)

# %% [markdown]
# #### Dropping Rows

# %%
#look at rows with missing data 
X_all.isnull().sum(axis=1).hist()
plt.title("distribution of missing values")
plt.show()
temp_X = pd.DataFrame({"rownull":X_all.isnull().sum(axis=1)})
#there is a group of ~ 100 row missing 29 or more values
# get index of these rows and drop 
drop_rate_row = 25
# returns which rows to drop in both X and Y dataframe
to_drop = temp_X.index[temp_X['rownull'] > drop_rate_row].tolist()

# %%
#check that rows bring dropped not all fraud  - 
print(y_all.iloc[to_drop].shape)
print(y_all.iloc[to_drop].sum())
# Out:
# (144, 1)
# fraud    8
# dtype: int64

# %%
#how many rows are going to be dropped?
print(len(to_drop))
#axis = 0, dropping rows
X_all = X_all.drop(to_drop,axis=0)
y_all = y_all.drop(to_drop,axis=0)
# Out:
# 144

# %%
print("X shape: ", X_all.shape)
print("y shape: ",y_all.shape)
X_all.isnull().sum(axis=1).hist()
plt.title("distribution of missing values")
# Out:
# X shape:  (3013, 37)
# y shape:  (3013, 1)
# Text(0.5,1,'distribution of missing values')

# %% [markdown]
# ### Imputation using expectation maximzation

# %%
temp = impy.em(X_all.values)
X_all[X_all.columns] = temp

# %%
# dataset before normalization
print("X shape ", X_all.shape)
print("y shape ",y_all.shape)

f = y_all.fraud.sum()
n = y_all.shape[0]-f
print("fraud ", f)
print("normal ", n)
print("fraud/all", round(f/X_all.shape[0],2))
X_all=X_all.reset_index(drop=True)
y_all=y_all.reset_index(drop=True)
# X_all.to_csv('X.csv')
# y_all.to_csv('y.csv')
# Out:
# X shape  (3013, 37)
# y shape  (3013, 1)
# fraud  621
# normal  2392
# fraud/all 0.21

# %% [markdown]
# ### Data exploration

# %%
y = [y_all.fraud.sum(), y_all[y_all.fraud == 0].shape[0]]
plt.hist(y_all, bins=2)
plt.show()
sns.set(rc={'figure.figsize':(11.7,8.27)})
corr = X_all.corr()
fig, ax = plt.subplots()
sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)],xticklabels=True, yticklabels=True, linewidths=.5, ax=ax, annot=True,annot_kws={"size": 9},cbar=False)
ax.tick_params(labelsize=15)
print("Not fraud (0), ",y[1])
print("Fraud (1), ",y[0])
# Out:
# Not fraud (0),  2392
# Fraud (1),  621

# %%
# printing multiple histograms at a time
def allHistograms(df):
    for i, col in enumerate(df.columns):
        plt.figure(i)
        plt.hist(df[col],bins=20,normed=True)
        plt.title(col + " (20 bins)")

# pairwise scatter plots with histograms on diagonal
# don't run will all features at once 
def pairwiseHistogramsScatter(start, stop, df, y):
    sns.set(font_scale=2)
    temp = df[df.columns[start:stop]]
    temp["fraud"] = y["fraud"]
    g = sns.PairGrid(temp, hue="fraud")
    g.map_diag(plt.hist)
    g.map_offdiag(plt.scatter)
    g.add_legend();

# %%
pairwiseHistogramsScatter(20,35,X_all,y_all)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
def scatterpairwise(x_col,y_col,text,label,scatterdf):
    sns.set(font_scale=1.5)
    sns.lmplot(x=x_col , y=y_col, data=scatterdf, hue=label,palette='hls', fit_reg=False,size= 8, aspect=5/3, legend_out=False)
    plt.title(x_col + " vs "+y_col)
    for line in range(0,scatterdf.shape[0]):
        plt.text(scatterdf[x_col].iloc[line]+0.2, scatterdf[y_col].iloc[line], "  "+str(scatterdf[text].iloc[line]), 
             horizontalalignment='left', size=9, color='black')
    
scatterdf = X_all.copy(deep=True)
scatterdf["fraud"] = y_all["fraud"]

scatterpairwise('dltt','dlc','new-comp','fraud',scatterdf)
scatterpairwise('ivao','lt','new-comp','fraud',scatterdf)
scatterpairwise('FIN','at','new-comp','fraud',scatterdf)
scatterpairwise('FIN','ceq','new-comp','fraud',scatterdf)
scatterpairwise('rect','sale','new-comp','fraud',scatterdf)

# %% [markdown]
# ### data + noise

# %%
# Need to split data into train validation test 
X_train, X_test, y_train, y_test = train_test_split(X_all.values, y_all.values, test_size=0.4, stratify=y_all.values,random_state=42, shuffle=True)
X_validate, X_test, y_validate, y_test = train_test_split(X_test, y_test,stratify=y_test, test_size=0.5, random_state=42, shuffle=True)
print("Train: ", X_train.shape)
print("Validate: ", X_validate.shape)
print("Test: ", X_test.shape)

transformer = MinMaxScaler(feature_range=(0, 1)).fit(X_train)
X_train = transformer.transform(X_train)
X_validate = transformer.transform(X_validate)
X_test = transformer.transform(X_test)

# create noisy data for train and test
noise_factor = 0.5
x_train_noisy = X_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape)
x_validate_noisy = X_validate + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_validate.shape)
x_test_noisy = X_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_test.shape)


x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_validate_noisy = np.clip(x_validate_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
# Out:
# Train:  (1807, 37)
# Validate:  (603, 37)
# Test:  (603, 37)

# %% [markdown]
# ### Denoising Autoencoder

# %%
def autoencoder(numFeatures):
    #input
    inData = Input(shape=(numFeatures,))
    act2 = 'sigmoid'
    #encoding
    rate = 0.5
    dr = Dropout(rate, noise_shape=None, seed=42)(inData)
    encoded = Dense(8, activation=act2, 
                kernel_initializer=keras.initializers.RandomUniform(seed=42),kernel_regularizer=regularizers.l1(0.01))(dr)
    dr = Dropout(rate, noise_shape=None, seed=42)(encoded)
    
    #latent layer
    latent = Dense(3,activation= act2)(dr)
    dr = Dropout(rate, noise_shape=None, seed=42)(latent)
    
    #decoding
    decoded = Dense(8,activation= act2)(dr)
    dr = Dropout(rate, noise_shape=None, seed=42)(decoded)
    
    outData = Dense(numFeatures, activation="sigmoid")(dr)
    autoencoder = Model(inData, outData)
    return autoencoder

# %%
batch_size = 32
epochs = 1000
# input shape is 1x# of features
features = X_all.shape[1]
ae = autoencoder(features)
ae.summary()

ae.compile(metrics=['accuracy'], loss='mean_squared_error', optimizer=Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False))

# lr=0.00001
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_49 (InputLayer)        (None, 37)                0
# _________________________________________________________________
# dropout_195 (Dropout)        (None, 37)                0
# _________________________________________________________________
# dense_205 (Dense)            (None, 8)                 304
# _________________________________________________________________
# dropout_196 (Dropout)        (None, 8)                 0
# _________________________________________________________________
# dense_206 (Dense)            (None, 3)                 27
# _________________________________________________________________
# dropout_197 (Dropout)        (None, 3)                 0
# _________________________________________________________________
# dense_207 (Dense)            (None, 8)                 32
# _________________________________________________________________
# dropout_198 (Dropout)        (None, 8)                 0
# _________________________________________________________________
# dense_208 (Dense)            (None, 37)                333
# =================================================================
# Total params: 696
# Trainable params: 696
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)

tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                      write_graph=True,
                          write_images=True)


history = ae.fit(x_train_noisy, X_train, batch_size=batch_size, epochs=epochs,
          verbose=0, shuffle=True, validation_data=(x_validate_noisy, X_validate),
          callbacks=[checkpointer, tensorboard]).history

# %%
fig = plt.figure(figsize = (10,10))
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss',size=20)
plt.ylabel('loss',size=20)
plt.xlabel('epoch',size=20)
plt.legend(['train', 'validation'], loc='upper right');

# %%
# noisy train
latent_layer = K.function([ae.layers[0].input], [ae.layers[4].output])
compressed = latent_layer([x_train_noisy])[0]
fig = plt.figure(figsize = (10,10))
ax = Axes3D(fig)
#ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('', fontsize = 15)
ax.set_ylabel('', fontsize = 15)
ax.set_title('Latent Layer w. Training Data', fontsize = 20)
targets = [1,0]
colours = ['r', 'b']
for target, colour in zip(targets,colours):
    indicesToKeep = y_train == target
    ax.scatter(compressed[indicesToKeep[:,0],0]
               , compressed[indicesToKeep[:,0],1],
               compressed[indicesToKeep[:,0],2]
               , c = colour
               ,alpha=0.3,label=str(target),s=20)
    ax.legend()
    
# train
latent_layer = K.function([ae.layers[0].input], [ae.layers[4].output])
compressed = latent_layer([X_train])[0]
fig = plt.figure(figsize = (10,10))
ax = Axes3D(fig)
#ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('', fontsize = 15)
ax.set_ylabel('', fontsize = 15)
ax.set_title('Latent Layer w. Training Data', fontsize = 20)
targets = [1,0]
colours = ['r', 'b']
for target, colour in zip(targets,colours):
    indicesToKeep = y_train == target
    ax.scatter(compressed[indicesToKeep[:,0],0]
               , compressed[indicesToKeep[:,0],1],
               compressed[indicesToKeep[:,0],2]
               , c = colour
               ,alpha=0.3,label=str(target),s=20)
    ax.legend()

# %%
latent_layer = K.function([ae.layers[0].input], [ae.layers[4].output])
compressed = latent_layer([x_test_noisy])[0]
fig = plt.figure(figsize = (10,10))
ax = Axes3D(fig)
ax.set_xlabel('', fontsize = 15)
ax.set_ylabel('', fontsize = 15)
ax.set_title('Latent Layer w. Test Data', fontsize = 20)
targets = [1,0]
colours = ['r', 'b']
for target, colour in zip(targets,colours):
    indicesToKeep = y_test == target
    ax.scatter(compressed[indicesToKeep[:,0],0]
               , compressed[indicesToKeep[:,0],1],
               compressed[indicesToKeep[:,0],2],
                c = colour
               ,  alpha=0.3,label=str(target),s=20)
    ax.legend()

latent_layer = K.function([ae.layers[0].input], [ae.layers[4].output])
compressed = latent_layer([X_test])[0]
fig = plt.figure(figsize = (10,10))
ax = Axes3D(fig)
ax.set_xlabel('', fontsize = 15)
ax.set_ylabel('', fontsize = 15)
ax.set_title('Latent Layer w. Test Data', fontsize = 20)
targets = [1,0]
colours = ['r', 'b']
for target, colour in zip(targets,colours):
    indicesToKeep = y_test == target
    ax.scatter(compressed[indicesToKeep[:,0],0]
               , compressed[indicesToKeep[:,0],1],
               compressed[indicesToKeep[:,0],2],
                c = colour
               ,  alpha=0.3,label=str(target),s=20)
    ax.legend()

# %% [markdown]
# ### Stacked Denoising Autoencoder using https://github.com/AmirAlavi/tied-autoencoder-keras

# %%
from tied_autoencoder_keras import DenseLayerAutoencoder

# %%
inputs =Input(shape=(X_all.shape[1],))
x = DenseLayerAutoencoder([8, 3], activation='sigmoid',dropout=0.5)(inputs)
model = Model(inputs=inputs, outputs=x)
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_47 (InputLayer)        (None, 37)                0
# _________________________________________________________________
# dense_layer_autoencoder_5 (D (None, 37)                376
# =================================================================
# Total params: 376
# Trainable params: 376
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size = 32
epochs = 1000
# input shape is 1x# of features
features = X_all.shape[1]

model.compile(metrics=['accuracy'], loss='mean_squared_error', optimizer=Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False))


checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)

tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                      write_graph=True,
                          write_images=True)


history = model.fit(x_train_noisy, X_train, batch_size=batch_size, epochs=epochs,
          verbose=0, shuffle=True, validation_data=(x_validate_noisy, X_validate),
          callbacks=[checkpointer, tensorboard]).history

# %%
fig = plt.figure(figsize = (10,10))
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss',size=20)
plt.ylabel('loss',size=20)
plt.xlabel('epoch',size=20)
plt.legend(['train', 'validation'], loc='upper right');

# %%
latent_layer = K.function([model.layers[1].input], [model.layers[1].encode(inputs)])
compressed = latent_layer([x_train_noisy])[0]

fig = plt.figure(figsize = (10,10))
ax = Axes3D(fig)
#ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('', fontsize = 15)
ax.set_ylabel('', fontsize = 15)
ax.set_title('Latent Layer w. Training Data', fontsize = 20)
targets = [1,0]
colours = ['r', 'b']
for target, colour in zip(targets,colours):
    indicesToKeep = y_train == target
    ax.scatter(compressed[indicesToKeep[:,0],0]
               , compressed[indicesToKeep[:,0],1],
               compressed[indicesToKeep[:,0],2]
               , c = colour
               ,alpha=0.3,label=str(target),s=10)
    ax.legend()


latent_layer = K.function([model.layers[1].input], [model.layers[1].encode(inputs)])
compressed = latent_layer([X_train])[0]

fig = plt.figure(figsize = (10,10))
ax = Axes3D(fig)
#ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('', fontsize = 15)
ax.set_ylabel('', fontsize = 15)
ax.set_title('Latent Layer w. Training Data', fontsize = 20)
targets = [1,0]
colours = ['r', 'b']
for target, colour in zip(targets,colours):
    indicesToKeep = y_train == target
    ax.scatter(compressed[indicesToKeep[:,0],0]
               , compressed[indicesToKeep[:,0],1],
               compressed[indicesToKeep[:,0],2]
               , c = colour
               ,alpha=0.3,label=str(target),s=10)
    ax.legend()

# %%
latent_layer = K.function([model.layers[1].input], [model.layers[1].encode(inputs)])
compressed = latent_layer([x_test_noisy])[0]

fig = plt.figure(figsize = (10,10))
ax = Axes3D(fig)
#ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('', fontsize = 15)
ax.set_ylabel('', fontsize = 15)
ax.set_title('Latent Layer w. Training Data', fontsize = 20)
targets = [1,0]
colours = ['r', 'b']
for target, colour in zip(targets,colours):
    indicesToKeep = y_test == target
    ax.scatter(compressed[indicesToKeep[:,0],0]
               , compressed[indicesToKeep[:,0],1],
               compressed[indicesToKeep[:,0],2]
               , c = colour
               ,alpha=0.3,label=str(target),s=10)
    ax.legend()
    
    
latent_layer = K.function([model.layers[1].input], [model.layers[1].encode(inputs)])
compressed = latent_layer([X_test])[0]

fig = plt.figure(figsize = (10,10))
ax = Axes3D(fig)
#ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('', fontsize = 15)
ax.set_ylabel('', fontsize = 15)
ax.set_title('Latent Layer w. Training Data', fontsize = 20)
targets = [1,0]
colours = ['r', 'b']
for target, colour in zip(targets,colours):
    indicesToKeep = y_test == target
    ax.scatter(compressed[indicesToKeep[:,0],0]
               , compressed[indicesToKeep[:,0],1],
               compressed[indicesToKeep[:,0],2]
               , c = colour
               ,alpha=0.3,label=str(target),s=10)
    ax.legend()
